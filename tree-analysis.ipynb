# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

trees = pd.read_csv('/Users/Akshay/Documents/IOT/Street_Tree_List.csv')
trees.dropna(axis=0,how='any')

species = trees['qSpecies']

# %%
# Out:
#     TreeID                  qLegalStatus  \
# 0   141565                Permitted Site
# 1   232565                  Undocumented
# 2   119263                DPW Maintained
# 3   207368                  Undocumented
# 4   188702                DPW Maintained
# 5   141566                Permitted Site
# 6   188697                DPW Maintained
# 7   122650                Permitted Site
# 8   203507                  Undocumented
# 9   122670                Permitted Site
# 10  122658                Permitted Site
# 11  122660                Permitted Site
# 12  122648                Permitted Site
# 13  196590  Planning Code 138.1 required
# 14  196591  Planning Code 138.1 required
# 15  122649                Permitted Site
# 16  145278                  Undocumented
# 17   96369                  Undocumented
# 18  182260                  Undocumented
# 19  251179  Planning Code 138.1 required
# 20  251178  Planning Code 138.1 required
# 21  203506                  Undocumented
# ...

# %%
species = trees['qSpecies'].map(lambda x: x.split(' :: '))
# Out:
# "Prunus serrulata 'Kwanzan' :: Kwanzan Flowering Cherry"

# %%
species = trees['qSpecies'].map(lambda x: x.split(' :: '))

# %%
for idx,spec in enumerate(species[:200]):
    if spec[0] == "Tree(s) ::" or spec[0] == "::":
        species.drop(species.index[idx], inplace=True) #delete the row in trees where trees[qSpecies][idx][0] = spec[0]
# Out:
# hi
# 27
# success
# hi
# 50
# success
# hi
# 53
# success
# hi
# 59
# success
# hi
# 61
# success
# hi
# 80
# success
# hi
# 93
# success
# hi
# 142
# success
# hi
# 167
# success
# hi
# 175
# success
# hi
# 178
# success

# %%
pd.merge(trees['qSpecies'],species, how='right')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-9ab159f67f80> in <module>()
# ----> 1 pd.merge(trees['qSpecies'],species, how='right')
#
# C:\Users\Akshay\Anaconda3\lib\site-packages\pandas\tools\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      59                          right_on=right_on, left_index=left_index,
#      60                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 61                          copy=copy, indicator=indicator)
#      62     return op.get_result()
#      63 if __debug__:
#
# C:\Users\Akshay\Anaconda3\lib\site-packages\pandas\tools\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     514             raise ValueError(
# ...
